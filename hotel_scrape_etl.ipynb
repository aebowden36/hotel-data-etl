# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import psycopg2
from bs4 import BeautifulSoup as bs
from splinter import Browser
import re

# %%
from webdriver_manager.chrome import ChromeDriverManager
executable_path = {'executable_path': ChromeDriverManager().install()}
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\Alyssa\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
url = "https://www.tripadvisor.com/Hotels-g34227-Fort_Lauderdale_Broward_County_Florida-Hotels.html"

browser = Browser('chrome', **executable_path, headless=False)
browser.visit(url)

html = browser.html
soup = bs(html, "html.parser")

# %%
property_title_class = soup.find_all(class_='property_title')
hotel_names = []
for content in property_title_class:
    hotel_name = content.text
    hotel_names.append(hotel_name)

# %%
hotel_names
# Out:
# ['      B Ocean Resort Fort Lauderdale',
#  '      Ocean Manor Beach Resort Hotel',
#  '      The Westin Fort Lauderdale',
#  '      Riverside Hotel',
#  '      Ocean Sky Hotel & Resort',
#  '      GALLERYone - A DoubleTree Suites by Hilton Hotel',
#  '      Snooze',
#  '      Hotel Maren Fort Lauderdale Beach',
#  '      Hyatt Centric Las Olas Fort Lauderdale',
#  '      Embassy Suites by Hilton Fort Lauderdale 17th Street',
#  '      The Westin Fort Lauderdale Beach Resort',
#  '      Cambria Hotel Fort Lauderdale Beach',
#  '      Hyatt Place Fort Lauderdale Cruise Port',
#  '      Courtyard By Marriott Fort Lauderdale Beach',
#  '      Best Western Plus Fort Lauderdale Airport/Cruise Port',
#  '      Bahia Mar Fort Lauderdale Beach - a DoubleTree by Hilton Hotel',
#  '      Renaissance Fort Lauderdale Cruise Port Hotel',
#  '      Deco Boutique Hotel',
#  '      Sun Tower Hotel & Suites',
#  '      The Dalmar, Fort Lauderdale, a Tribute Portfolio Hotel',
#  '      Best Western Plus Oceanside Inn',
#  '      Ocean Beach Club',
#  '      Marriott Hotel Fort Lauderdale North',
#  '      W Fort Lauderdale',
#  '      Hotel Motel Lauderdale Inn',
#  '      Hampton Inn Fort Lauderdale Airport North Cruise Port',
#  '      Crowne Plaza Ft. Lauderdale Airport/Cruise',
#  '      Lago Mar Beach Resort & Club',
#  '      Holiday Inn Express Hotel & Suites Ft. Lauderdale Airport/Cruise',
#  '      Hilton Fort Lauderdale Beach Resort',
#  '      Ocean Mile Hotel']

# %%
all_website_prices = soup.find_all("div",  {"class": ["priceBlock ui_column is-12-tablet", "price __resizeWatch"]})
    
website_price_results = []
split_list = []
popped_list = []
price_with_website = []
price_vals = []
    
for prices in all_website_prices:
    if len(prices.text) >= 5:
        website_price_results.append(prices.text)
    
for items in website_price_results:
    split_list.append(items.split("$"))
    
for items in split_list:
    items.pop(0)
    popped_list.append(items)
    
for items in popped_list:
    if len(items) == 1:
        price_with_website.append(items[0])
    else:
        price_with_website.append(items[1])
    
for items in price_with_website:
    result = re.sub('[^0-9]','', items)
    int_results = int(result)
    price_vals.append(int_results)
rating_links = soup.find_all("a",  {"class":'ui_bubble_rating'})
hotel_ratings = []
    
for link in rating_links:
    alt_text = link.get('alt')
    split_text = alt_text.split(" ")
    rating = float(split_text[0])
    hotel_ratings.append(rating)
    
#return(hotel_names, price_vals, hotel_ratings)

# %%
scrape_df = pd.DataFrame({'hotel_name':hotel_names, 'price':price_vals, 'ratings':hotel_ratings})
scrape_df
# Out:
#                                            hotel_name  price  ratings
# 0                      B Ocean Resort Fort Lauderdale    242      4.5
# 1                      Ocean Manor Beach Resort Hotel    174      4.0
# 2                          The Westin Fort Lauderdale    135      4.0
# 3                                     Riverside Hotel    149      4.0
# 4                            Ocean Sky Hotel & Resort    239      3.5
# 5         GALLERYone - A DoubleTree Suites by Hilt...    144      4.0
# 6                                              Snooze    160      4.5
# 7                   Hotel Maren Fort Lauderdale Beach    298      5.0
# 8              Hyatt Centric Las Olas Fort Lauderdale    203      4.5
# 9         Embassy Suites by Hilton Fort Lauderdale...    189      4.0
# 10            The Westin Fort Lauderdale Beach Resort    246      4.5
# 11                Cambria Hotel Fort Lauderdale Beach    199      4.5
# 12            Hyatt Place Fort Lauderdale Cruise Port    152      4.0
# 13        Courtyard By Marriott Fort Lauderdale Beach    238      4.0
# 14        Best Western Plus Fort Lauderdale Airpor...     93      4.0
# 15        Bahia Mar Fort Lauderdale Beach - a Doub...    167      3.5
# 16        Renaissance Fort Lauderdale Cruise Port ...    209      4.0
# 17                                Deco Boutique Hotel    169      4.0
# 18                           Sun Tower Hotel & Suites    269      4.5
# 19        The Dalmar, Fort Lauderdale, a Tribute P...    239      3.5
# 20                    Best Western Plus Oceanside Inn    184      4.0
# 21                                   Ocean Beach Club     99      4.0
# 22               Marriott Hotel Fort Lauderdale North    119      4.0
# 23                                  W Fort Lauderdale    356      4.0
# 24                         Hotel Motel Lauderdale Inn    109      4.5
# 25        Hampton Inn Fort Lauderdale Airport Nort...    139      4.5
# 26         Crowne Plaza Ft. Lauderdale Airport/Cruise    139      4.0
# 27                       Lago Mar Beach Resort & Club    215      4.5
# 28        Holiday Inn Express Hotel & Suites Ft. L...    129      4.0
# 29                Hilton Fort Lauderdale Beach Resort    309      4.5
# 30                                   Ocean Mile Hotel     89      3.0

# %%
average_price_df = scrape_df.groupby('ratings').aggregate({'price': 'mean'}).reset_index()
average_price_df = average_price_df.rename(columns={'price':'average_price'})
average_price_df
# Out:
#    ratings  average_price
# 0      3.0         89.000
# 1      3.5        215.000
# 2      4.0        167.375
# 3      4.5        209.100
# 4      5.0        298.000

# %%
merged_df = scrape_df.merge(average_price_df)
merged_df
# Out:
#                                            hotel_name  price  ratings  \
# 0                      B Ocean Resort Fort Lauderdale    242      4.5
# 1                                              Snooze    160      4.5
# 2              Hyatt Centric Las Olas Fort Lauderdale    203      4.5
# 3             The Westin Fort Lauderdale Beach Resort    246      4.5
# 4                 Cambria Hotel Fort Lauderdale Beach    199      4.5
# 5                            Sun Tower Hotel & Suites    269      4.5
# 6                          Hotel Motel Lauderdale Inn    109      4.5
# 7         Hampton Inn Fort Lauderdale Airport Nort...    139      4.5
# 8                        Lago Mar Beach Resort & Club    215      4.5
# 9                 Hilton Fort Lauderdale Beach Resort    309      4.5
# 10                     Ocean Manor Beach Resort Hotel    174      4.0
# 11                         The Westin Fort Lauderdale    135      4.0
# 12                                    Riverside Hotel    149      4.0
# 13        GALLERYone - A DoubleTree Suites by Hilt...    144      4.0
# 14        Embassy Suites by Hilton Fort Lauderdale...    189      4.0
# 15            Hyatt Place Fort Lauderdale Cruise Port    152      4.0
# 16        Courtyard By Marriott Fort Lauderdale Beach    238      4.0
# 17        Best Western Plus Fort Lauderdale Airpor...     93      4.0
# 18        Renaissance Fort Lauderdale Cruise Port ...    209      4.0
# 19                                Deco Boutique Hotel    169      4.0
# 20                    Best Western Plus Oceanside Inn    184      4.0
# 21                                   Ocean Beach Club     99      4.0
# 22               Marriott Hotel Fort Lauderdale North    119      4.0
# 23                                  W Fort Lauderdale    356      4.0
# 24         Crowne Plaza Ft. Lauderdale Airport/Cruise    139      4.0
# 25        Holiday Inn Express Hotel & Suites Ft. L...    129      4.0
# 26                           Ocean Sky Hotel & Resort    239      3.5
# 27        Bahia Mar Fort Lauderdale Beach - a Doub...    167      3.5
# 28        The Dalmar, Fort Lauderdale, a Tribute P...    239      3.5
# 29                  Hotel Maren Fort Lauderdale Beach    298      5.0
# 30                                   Ocean Mile Hotel     89      3.0
#
#     average_price
# 0         209.100
# 1         209.100
# 2         209.100
# 3         209.100
# 4         209.100
# 5         209.100
# 6         209.100
# 7         209.100
# 8         209.100
# 9         209.100
# 10        167.375
# 11        167.375
# 12        167.375
# 13        167.375
# 14        167.375
# 15        167.375
# 16        167.375
# 17        167.375
# 18        167.375
# 19        167.375
# 20        167.375
# 21        167.375
# 22        167.375
# 23        167.375
# 24        167.375
# 25        167.375
# 26        215.000
# 27        215.000
# 28        215.000
# 29        298.000
# 30         89.000

# %%
#connect to local database
rds_connection_string = "postgres:postgres@localhost:5432/hotels_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#check table names
engine.table_names()
# Out:
# ['csv', 'scrape']

# %%
#load dataframe into database
merged_df.to_sql(name='scrape', con=engine, if_exists='append', index=False)

# %%
#confirm that dataframe has been properly loaded by querying table
pd.read_sql_query('select * from scrape', con=engine).head()
# Out:
#    id                                     hotel_name  price  ratings  \
# 0   1                 B Ocean Resort Fort Lauderdale    242      4.5
# 1   2                                         Snooze    160      4.5
# 2   3         Hyatt Centric Las Olas Fort Lauderdale    203      4.5
# 3   4        The Westin Fort Lauderdale Beach Resort    246      4.5
# 4   5            Cambria Hotel Fort Lauderdale Beach    199      4.5
#
#    average_price
# 0          209.1
# 1          209.1
# 2          209.1
# 3          209.1
# 4          209.1
